# %%
# 크롤링 필요 라이브러리 임포트

# 크롤링 작업을 위한 라이브러리 임포트
from bs4 import BeautifulSoup   # 웹에서 가져온 데이터를 정제하는 역할
import requests                 # 파이썬에서 다이렉트로 자료를 요청하는 역할
from selenium import webdriver # 크롬창을 켜주는 역할
import time                    # 코드 중간에 딜레이를 넣는 역할

# %%
# 셀레니움 기본세팅을 해주세요
# 알라딘 베스트셀러 페이지에 접속하도록 만들어주시면 됩니다.

browser = webdriver.Chrome('chromedriver.exe')


for i in range(21):
    browser.get("https://www.aladin.co.kr/shop/common/wbest.aspx?\
    BestType=Bestseller&BranchType=1&CID=0&page=%s&cnt=1000&SortOrder=1" % i)

    
    source = browser.page_source

    parsed_source =  BeautifulSoup(source, "html.parser")


    div_list = parsed_source.find_all("div",class_="ss_book_box")

for item in div_list:
    # for li in item.find_all("li"):
    li_list = item.find_all("li")
    
   # print(li_list[1].text)
   # print(li_list[2].text)
   # print(li_list[3].text)
   # print("----------------------------")
    if str(li_list[0].text)[0] ==  "[":
        
        print(li_list[1].text)
        print(li_list[2].text)
        print(li_list[3].text)
        print("----------------------------")
    else:
        print(li_list[0].text)
        print(li_list[1].text)
        print(li_list[2].text)
        print("----------------------------")

    
    time.sleep(2)
# Out:
# C:\Users\ict03-02\AppData\Local\Temp\ipykernel_7840\2635762061.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('chromedriver.exe')
# 디즈니 엔칸토 소설 (고급 벨벳 양장본 한정판)
# 앤절라 세르반테스 (지은이), 안세라 (옮긴이) | 아르누보 | 2022년 5월
# 13,800원 → 12,420원 (10%할인),  마일리지 690원 (5% 적립)
# ----------------------------
# 조국의 시간
# 조국 (지은이) | 한길사 | 2021년 5월
# 17,000원 → 15,300원 (10%할인),  마일리지 850원 (5% 적립)
# ----------------------------
# 아홉 살 마음 사전 ㅣ 아홉 살 사전
# 박성우 (지은이), 김효은 (그림) | 창비 | 2017년 3월
# 11,000원 → 9,900원 (10%할인),  마일리지 550원 (5% 적립)
# ----------------------------
# 자존감 수업 (100만 부 기념 스페셜 에디션)
# 윤홍균 (지은이) | 심플라이프 | 2016년 8월
# 14,000원 → 12,600원 (10%할인),  마일리지 700원 (5% 적립)
# ----------------------------
# 해커스 토익 실전 1000제 1 LC 리스닝 문제집 (Hackers TOEIC Listening) ㅣ 해커스 신토익
# 해커스어학연구소 (지은이) | 해커스어학연구소(Hackers) | 2018년 11월
# 11,900원 → 10,710원 (10%할인),  마일리지 590원 (5% 적립)
# ----------------------------
# ETS 토익 정기시험 기출문제집 1000 Vol.1 Reading ㅣ ETS 토익 정기시험 기출문제집
# ETS (엮은이) | (주)YBM(와이비엠) | 2018년 12월
# 17,800원 → 16,020원 (10%할인),  마일리지 890원 (5% 적립)
# ----------------------------
# 종의 기원
# 정유정 (지은이) | 은행나무 | 2016년 5월
# 13,000원 → 11,700원 (10%할인),  마일리지 650원 (5% 적립)
# ----------------------------
# 장군이네 떡집 ㅣ 난 책읽기가 좋아
# 레이 달리오 (지은이), 고영태 (옮긴이) | 한빛비즈 | 2018년 6월
# 35,000원 → 31,500원 (10%할인),  마일리지 1,750원 (5% 적립)
# ----------------------------
# 아름다운 초저녁달 1
# 야마모리 미카 (지은이) | 학산문화사(만화) | 2022년 1월
# 6,000원 → 5,400원 (10%할인),  마일리지 300원 (5% 적립)
# ----------------------------
# 아기곰의 재테크 불변의 법칙
# 아기곰 (지은이) | 아라크네 | 2021년 6월
# 19,000원 → 17,100원 (10%할인),  마일리지 950원 (5% 적립)
# ----------------------------
# 2022 사회조사분석사 2급 필기 한권으로 끝내기 + 무료강의(기출) ㅣ 2022 사회조사분석사 시리즈
# 이종익 (지은이) | 시대고시기획 | 2022년 4월
# 33,000원 → 29,700원 (10%할인),  마일리지 1,650원 (5% 적립)
# ----------------------------
# 시점의 힘 ㅣ 내 글이 작품이 되는 법
# 샌드라 거스 (지은이), 지여울 (옮긴이) | 윌북 | 2022년 4월
# 13,800원 → 12,420원 (10%할인),  마일리지 690원 (5% 적립)
# ----------------------------
# Re : 제로부터 시작하는 이세계 생활 28
# 나가츠키 탓페이 (지은이), 오츠카 신이치로 (그림), 정홍식 (옮긴이) | 영상출판미디어(주) | 2022년 5월
# 7,500원 → 6,750원 (10%할인),  마일리지 370원 (5% 적립)
# ----------------------------
# 나는 불안할 때 논어를 읽는다
# 판덩 (지은이), 이서연 (옮긴이) | 미디어숲 | 2022년 3월
# 17,800원 → 16,020원 (10%할인),  마일리지 890원 (5% 적립)
# ----------------------------
# 14살부터 시작하는 나의 첫 진로 수업
# 학연플러스 편집부 (지은이), 김신혜 (옮긴이), 이케가미 아키라 (감수), 카나 (만화), 모도로카 (일러스트) | 뜨인돌 | 2021년 4월
# 15,000원 → 13,500원 (10%할인),  마일리지 750원 (5% 적립)
# ----------------------------
# 간다아아!
# 코리 R. 테이버 (지은이), 노은정 (옮긴이) | 오늘책 | 2022년 3월
# 13,000원 → 11,700원 (10%할인),  마일리지 650원 (5% 적립)
# ----------------------------
# 교양이 쌓일 만두 하지?
# 팀 교양만두 (지은이) | 다산북스 | 2022년 4월
# 17,000원 → 15,300원 (10%할인),  마일리지 850원 (5% 적립)
# ----------------------------
# 두선생의 지도로 읽는 세계사 : 서양 편
# 한영준 (지은이) | 21세기북스 | 2022년 3월
# 18,000원 → 16,200원 (10%할인),  마일리지 900원 (5% 적립)
# ----------------------------
# 똑게육아
# 로리(김준희) (지은이) | 북로스트 | 2022년 2월
# 22,200원 → 19,980원 (10%할인),  마일리지 1,110원 (5% 적립)
# ----------------------------
# 2022 전한길 한국사능력검정시험 한능검 필기노트 (스프링)
# 전한길 (지은이) | 전한길한국사 | 2022년 4월
# 15,000원 → 13,500원 (10%할인),  마일리지 750원 (5% 적립)
# ----------------------------
# 2022 해커스공무원 실전동형모의고사 영어 2 12회 (9급공무원) ㅣ 2022 해커스 공무원 실전동형모의고사
# 해커스 공무원시험연구소 (지은이) | 해커스공무원 | 2022년 4월
# 17,000원 → 15,300원 (10%할인),  마일리지 850원 (5% 적립)
# ----------------------------
# 읽으면 수학천재가 되는 만화책 : 초등 A ㅣ 읽으면 수학천재가 되는 만화책
# Team. StoryG (지은이) | oldstairs(올드스테어즈) | 2022년 3월
# 14,000원 → 12,600원 (10%할인),  마일리지 700원 (5% 적립)
# ----------------------------
# 2022 에듀윌 답만보는 운전면허 필기 1종.2종 공통
# 도로교통공단 (지은이) | 에듀윌 | 2022년 2월
# 11,000원 → 9,900원 (10%할인),  마일리지 550원 (5% 적립)
# ----------------------------
# 내가 아는 나는 누구인가
# 리하르트 다비트 프레히트 (지은이), 윤순식, 원당희 (옮긴이) | (주)교학도서 | 2022년 2월
# 18,000원 → 16,200원 (10%할인),  마일리지 900원 (5% 적립)
# ----------------------------

# %%
# 1~20페이지까는 도는 코드를 작성했다면 
browser = webdriver.Chrome('chromedriver.exe')

time.sleep(2)

browser.get('https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=Bestseller&BranchType=1&CID=0&page=1&cnt=1000&SortOrder=1')
# Out:
# C:\Users\ict03-02\AppData\Local\Temp\ipykernel_7840\2285832112.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('chromedriver.exe')

# %%
source = browser.page_source

parsed_source =  BeautifulSoup(source, "html.parser")


div_list = parsed_source.find_all("div",class_="ss_book_box")

for item in div_list:
    # for li in item.find_all("li"):
    li_list = item.find_all("li")
    
   # print(li_list[1].text)
   # print(li_list[2].text)
   # print(li_list[3].text)
   # print("----------------------------")
    if str(li_list[0].text)[0] ==  "[":
        
        print(li_list[1].text)
        print(li_list[2].text)
        print(li_list[3].text)
        print("----------------------------")
    else:
        print(li_list[0].text)
        print(li_list[1].text)
        print(li_list[2].text)
        print("----------------------------")

    
    time.sleep(2)
# Out:
# 50

# %%
for item in div_list:
    # for li in item.find_all("li"):
    li_list = item.find_all("li")
    
   # print(li_list[1].text)
   # print(li_list[2].text)
   # print(li_list[3].text)
   # print("----------------------------")
    if str(li_list[0].text)[0] ==  "[":
        
        print(li_list[1].text)
        print(li_list[2].text)
        print(li_list[3].text)
        print("----------------------------")
    else:
        print(li_list[0].text)
        print(li_list[1].text)
        print(li_list[2].text)
        print("----------------------------")

    
    time.sleep(2)
# Out:
# 작별인사
# 김영하 (지은이) | 복복서가 | 2022년 5월
# 14,000원 → 12,600원 (10%할인),  마일리지 700원 (5% 적립)
# ----------------------------
# 설민석의 한국사 대모험 21 ㅣ 설민석의 한국사 대모험 21
# 설민석, 스토리박스 (지은이), 정현희 (그림), 강석화 (감수) | 단꿈아이 | 2022년 5월
# 13,000원 → 11,700원 (10%할인),  마일리지 650원 (5% 적립)
# ----------------------------
# 감정 어휘
# 유선경 (지은이) | 앤의서재 | 2022년 6월
# 16,000원 → 14,400원 (10%할인),  마일리지 800원 (5% 적립)
# ----------------------------
# 인플레이션에서 살아남기
# 오건영 (지은이) | 페이지2(page2) | 2022년 5월
# 18,800원 → 16,920원 (10%할인),  마일리지 940원 (5% 적립)
# ----------------------------
# 최재천의 공부
# 최재천, 안희경 (지은이) | 김영사 | 2022년 5월
# 16,500원 → 14,850원 (10%할인),  마일리지 820원 (5% 적립)
# ----------------------------
# 역행자
# 자청 (지은이) | 웅진지식하우스 | 2022년 6월
# 17,500원 → 15,750원 (10%할인),  마일리지 870원 (5% 적립)
# ----------------------------
# 읽지 않은 책에 대해 말하는 법 ㅣ 패러독스 1
# 피에르 바야르 (지은이), 김병욱 (옮긴이) | 여름언덕 | 2008년 2월
# 12,000원 → 10,800원 (10%할인),  마일리지 600원 (5% 적립)
# ----------------------------
# 정재승의 인간 탐구 보고서 9 ㅣ 어린이를 위한 뇌과학 프로젝트
# 정재은, 이고은 (글), 김현민 (그림), 정재승 (기획) | 아울북 | 2022년 5월
# 14,000원 → 12,600원 (10%할인),  마일리지 700원 (5% 적립)
# ----------------------------
# 2022 제5회 한국과학문학상 수상작품집
# 서윤빈, 김혜윤, 김쿠만, 김필산, 성수나, 이멍 (지은이) | 허블 | 2022년 5월
# 6,000원 → 5,400원 (10%할인),  마일리지 300원 (5% 적립)
# ----------------------------
# 세상의 마지막 기차역
# 무라세 다케시 (지은이), 김지연 (옮긴이) | 모모 | 2022년 5월
# 14,000원 → 12,600원 (10%할인),  마일리지 700원 (5% 적립)
# ----------------------------
# 물고기는 존재하지 않는다
# 룰루 밀러 (지은이), 정지인 (옮긴이) | 곰출판 | 2021년 12월
# 17,000원 → 15,300원 (10%할인),  마일리지 850원 (5% 적립)
# ----------------------------
# 변화하는 세계 질서
# 레이 달리오 (지은이), 송이루, 조용빈 (옮긴이) | 한빛비즈 | 2022년 6월
# 38,000원 → 34,200원 (10%할인),  마일리지 1,900원 (5% 적립)
# ----------------------------
# Go Go 카카오프렌즈 24 : 스웨덴 ㅣ Go Go 카카오프렌즈 24
# 김미영 (지은이), 김정한 (그림) | 아울북 | 2022년 5월
# 12,000원 → 10,800원 (10%할인),  마일리지 600원 (5% 적립)
# ----------------------------
# 코드네임 S ㅣ 456 Book 클럽
# 강경수 (지은이) | 시공주니어 | 2022년 5월
# 12,000원 → 10,800원 (10%할인),  마일리지 600원 (5% 적립)
# ----------------------------
# 어느 날 공주가 되어버렸다 7 (루카스 아크릴 스탠드 + 퍼즐 + 초판 한정 부록 엽서 + 홀로그램 엽서 6종 포함 한정판)
# 스푼 (지은이), 플루토스 (원작) | 캐롯툰 | 2022년 9월
# 37,000원 → 33,300원 (10%할인),  마일리지 1,850원 (5% 적립)
# ----------------------------
# 불편한 편의점 (40만부 기념 벚꽃 에디션)
# 김호연 (지은이) | 나무옆의자 | 2021년 4월
# 14,000원 → 12,600원 (10%할인),  마일리지 700원 (5% 적립)
# ----------------------------
# 내가 틀릴 수도 있습니다
# 비욘 나티코 린데블라드 (지은이), 토마스 산체스 (그림), 박미경 (옮긴이) | 다산초당(다산북스) | 2022년 4월
# 어느 날, 내 죽음에 네가 들어왔다
# 세이카 료겐 (지은이), 김윤경 (옮긴이) | 모모 | 2022년 5월
# 15,000원 → 13,500원 (10%할인),  마일리지 750원 (5% 적립)
# ----------------------------
# 2022 큰별쌤 최태성의 별★별한국사 기출 500제 한국사능력검정시험 심화 (1.2.3급) ㅣ 큰별쌤 최태성의 별★별한국사 한국사능력검정시험 시리즈
# 최태성 (지은이) | 이투스북 | 2021년 12월
# 19,500원 → 17,550원 (10%할인),  마일리지 970원 (5% 적립)
# ----------------------------
# 먼작귀 1 (그림책 포함 특별판)
# 나가노 (지은이) | 미우(대원씨아이) | 2022년 6월
# 17,000원 → 15,300원 (10%할인),  마일리지 850원 (5% 적립)
# ----------------------------
# 행성 2 ㅣ 고양이 시리즈
# 베르나르 베르베르 (지은이), 전미연 (옮긴이) | 열린책들 | 2022년 5월
# 16,800원 → 15,120원 (10%할인),  마일리지 840원 (5% 적립)
# ----------------------------
# 긴긴밤 ㅣ 보름달문고 83
# 루리 (지은이) | 문학동네 | 2021년 2월
# 11,500원 → 10,350원 (10%할인),  마일리지 570원 (5% 적립)
# ----------------------------
# ETS 토익 정기시험 기출문제집 1000 Vol. 3 Reading (리딩) ㅣ ETS 토익 정기시험 기출문제집
# ETS (엮은이) | (주)YBM(와이비엠) | 2021년 12월
# 17,800원 → 16,020원 (10%할인),  마일리지 890원 (5% 적립)
# ----------------------------
# 모든 것은 기본에서 시작한다
# 손웅정 (지은이) | 수오서재 | 2021년 10월
# 16,000원 → 14,400원 (10%할인),  마일리지 800원 (5% 적립)
# ----------------------------
# 5년 후 나에게 - Q&A a day (2022 메리골드 Edition)
# 포터 스타일 (지은이), 정지현 (옮긴이) | 토네이도 | 2021년 11월
# 16,800원 → 15,120원 (10%할인),  마일리지 840원 (5% 적립)
# ----------------------------
# 나는 대출 없이 0원으로 소형 아파트를 산다
# 잭파시(최경천) (지은이) | 다산북스 | 2022년 4월
# 20,000원 → 18,000원 (10%할인),  마일리지 1,000원 (5% 적립)
# ----------------------------
# 애쓰지 않아도 ㅣ 마음산책 짧은 소설
# 최은영 (지은이), 김세희 (그림) | 마음산책 | 2022년 4월
# 14,500원 → 13,050원 (10%할인),  마일리지 720원 (5% 적립)
# ----------------------------
# 이어령의 마지막 수업
# 김지수 (지은이), 이어령 | 열림원 | 2021년 10월
# 16,500원 → 14,850원 (10%할인),  마일리지 820원 (5% 적립)
# ----------------------------
# 뭐가 다를까? 다른그림찾기 1000 ㅣ 놀면서 똑똑해지는 퍼즐북 시리즈
# 레이크 프레스 (구성) | 길벗스쿨 | 2022년 5월
# 8,800원 → 7,920원 (10%할인),  마일리지 440원 (5% 적립)
# ----------------------------
# 해커스 토익 기출 보카 TOEIC VOCA 단어장
# David Cho (지은이) | 해커스어학연구소(Hackers) | 2019년 1월
# 12,900원 → 11,610원 (10%할인),  마일리지 640원 (5% 적립)
# ----------------------------
# 흔한남매 10 ㅣ 흔한남매 10
# 흔한남매 (지은이), 백난도 (글), 유난희 (그림), 흔한컴퍼니 (감수) | 미래엔아이세움 | 2022년 4월
# 13,500원 → 12,150원 (10%할인),  마일리지 670원 (5% 적립)
# ----------------------------
# ETS 토익 정기시험 기출문제집 1000 Vol. 3 Listening (리스닝) ㅣ ETS 토익 정기시험 기출문제집
# ETS (엮은이) | (주)YBM(와이비엠) | 2021년 12월
# 17,800원 → 16,020원 (10%할인),  마일리지 890원 (5% 적립)
# ----------------------------
# 기브앤테이크 Give and Take
# 애덤 그랜트 (지은이), 윤태준 (옮긴이) | 생각연구소 | 2013년 6월
# 17,500원 → 15,750원 (10%할인),  마일리지 870원 (5% 적립)
# ----------------------------
# 낙원 ㅣ 문학동네 세계문학전집 211
# 압둘라자크 구르나 (지은이), 왕은철 (옮긴이) | 문학동네 | 2022년 5월
# 15,000원 → 13,500원 (10%할인),  마일리지 750원 (5% 적립)
# ----------------------------
# 거의 모든 행동 표현의 영어
# 서영조 (지은이) | 사람in | 2022년 3월
# 16,000원 → 14,400원 (10%할인),  마일리지 800원 (5% 적립)
# ----------------------------
# 굿모닝 해빗
# 멜 로빈스 (지은이), 강성실 (옮긴이) | 쌤앤파커스 | 2022년 5월
# 16,000원 → 14,400원 (10%할인),  마일리지 800원 (5% 적립)
# ----------------------------
# 둥실이네 떡집 ㅣ 난 책읽기가 좋아
# 김리리 (지은이), 김이랑 (그림) | 비룡소 | 2022년 4월
# 11,000원 → 9,900원 (10%할인),  마일리지 550원 (5% 적립)
# ----------------------------

# %%
# 셀레니움 기본세팅을 해주세요
# 알라딘 베스트셀러 페이지에 접속하도록 만들어주시면 됩니다.

browser = webdriver.Chrome('chromedriver.exe')


for i in range(21):
    browser.get("https://www.aladin.co.kr/shop/common/wbest.aspx?\
    BestType=Bestseller&BranchType=1&CID=0&page=%s&cnt=1000&SortOrder=1" % i)
    
    time.sleep(2)
    
    source = browser.page_source

    parsed_source =  BeautifulSoup(source, "html.parser")

    f=codecs.open("C:/crawler1/aladin.txt", encoding="utf-8", mode="w")

    div_list = parsed_source.find_all("div",class_="ss_book_box")
    for item in div_list:
    # for li in item.find_all("li"):
        li_list = item.find_all("li")
    
   # print(li_list[1].text)
   # print(li_list[2].text)
   # print(li_list[3].text)
   # print("----------------------------")
        if str(li_list[0].text)[0] ==  "[":
            f.write(li_list[1].text.replace(",","") + ",")
            f.write(li_list[2].text.replace(",","") + ",")
            f.write(li_list[3].text.replace(",","") + "\n")
        
        else:
            f.write(li_list[0].text.replace(",","") + ",")
            f.write(li_list[1].text.replace(",","") + ",")
            f.write(li_list[2].text.replace(",","") + "\n")
    
    
f.close()
# Out:
# C:\Users\ict03-02\AppData\Local\Temp\ipykernel_7840\2335113480.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('chromedriver.exe')

# %%
# 라이브러리 임포트
import codecs
f=codecs.open("C:/crawler1/aladin.txt", encoding="utf-8", mode="w")
f.close()

# %%
f.close()
